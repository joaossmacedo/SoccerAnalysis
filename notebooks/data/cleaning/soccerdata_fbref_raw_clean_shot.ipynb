# %% [markdown]
# <a href="https://colab.research.google.com/github/joaossmacedo/SoccerAnalysis/blob/main/notebooks/data/cleaning/soccerdata_fbref_raw_clean_shot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
# !python3 -m pip install soccerdata
import soccerdata as sd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ...
# [06/08/25 02:34:07] INFO     No custom team name replacements found. You can configure these in       ]8;id=457951;file:///usr/local/lib/python3.11/dist-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=310446;file:///usr/local/lib/python3.11/dist-packages/soccerdata/_config.py#91\91]8;;\
#                              /root/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=143894;file:///usr/local/lib/python3.11/dist-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=694678;file:///usr/local/lib/python3.11/dist-packages/soccerdata/_config.py#197\197]8;;\
#                              /root/soccerdata/config/league_dict.json.

# %%
# pd.set_option('display.height', 500)
import pandas as pd
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # Params

# %%
st = 2017
ed = 2025

path_input = f'/content/drive/My Drive/database/soccerdata/fbref/raw/shot_events/'
path_output = f'/content/drive/My Drive/database/soccerdata/fbref/raw_clean/shot_events/'

# %% [markdown]
# # Code

# %% [markdown]
# ## Prepare colab

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

os.makedirs(path_output, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Utils

# %%
rename_dict = {
  'SCA 1_player': 'SCA_1_player',
  'SCA 1_event': 'SCA_1_event',
  'SCA 2_player': 'SCA_2_player',
  'SCA 2_event': 'SCA_2_event',
}

# %%
def flatten_columns(df):
  cols = []
  for v0, v1, v2 in zip(df.columns.get_level_values(0), df.columns.get_level_values(1), df.columns.get_level_values(2)):
    text = ''
    if not v0.startswith('Unnamed'):
      text += f'{v0}_'
    if not v1.startswith('Unnamed'):
      text += f'{v1}_'
    if not v2.startswith('Unnamed'):
      text += f'{v2}_'
    text = text[:-1]

    cols.append(text)

  df.columns = cols
  return df

# %% [markdown]
# ## Getting Data

# %%
df = None
for y in range(st, ed):
  print('-'*50)
  print(y)

  path_input_year = f'{path_input}{y}/'

  path_input_year_csv = f'{path_input_year}database.csv'
  if not os.path.exists(path_input_year_csv):
    print('missing')
    continue

  df_year = pd.read_csv(path_input_year_csv, header=[0, 1, 2])
  df_year = flatten_columns(df_year)
  df_year = df_year.rename(columns=rename_dict)

  if df is None:
    df = df_year
  else:
    df = pd.concat([df, df_year])

df = df.reset_index(drop=True)
df
# Out:
# --------------------------------------------------
# 2017
# --------------------------------------------------
# 2018
# --------------------------------------------------
# 2019
# --------------------------------------------------
# 2020
# --------------------------------------------------
# 2021
# --------------------------------------------------
# 2022
# --------------------------------------------------
# 2023
# --------------------------------------------------
# 2024
#                     league  season                               game minute  \
# 0       ENG-Premier League    1718  2017-08-11 Arsenal-Leicester City      2
# 1       ENG-Premier League    1718  2017-08-11 Arsenal-Leicester City      4
# 2       ENG-Premier League    1718  2017-08-11 Arsenal-Leicester City      5
# 3       ENG-Premier League    1718  2017-08-11 Arsenal-Leicester City      8
# 4       ENG-Premier League    1718  2017-08-11 Arsenal-Leicester City     14
# ...

# %% [markdown]
# ## Validating notes

# %%
display(df['notes'].value_counts().head(5))
# Out:
# notes
# Volley                  40000
# Free kick               13290
# Deflected                7747
# Deflected, Volley         677
# Free kick, Deflected      274
# Name: count, dtype: int64

# %% [markdown]
# ## Spliting notes into calls

# %%
for note in ['Volley', 'Free kick', 'Deflected']:
  df[f'is_{note.lower().replace(" ", "")}'] = df['notes'].apply(lambda x: note in x if isinstance(x, str) else False).astype('int')
df.head(2)
# Out:
#                league  season                               game minute  \
# 0  ENG-Premier League    1718  2017-08-11 Arsenal-Leicester City      2
# 1  ENG-Premier League    1718  2017-08-11 Arsenal-Leicester City      4
#
#                 player            team    xG  PSxG     outcome  distance  \
# 0  Alexandre Lacazette         Arsenal  0.06  0.37        Goal        13
# 1         Riyad Mahrez  Leicester City  0.08   NaN  Off Target        17
#
#    body_part notes    SCA_1_player  SCA_1_event     SCA_2_player  SCA_2_event  \
# 0       Head   NaN  Mohamed Elneny  Pass (Live)  Héctor Bellerín  Pass (Live)
# 1  Left Foot   NaN             NaN          NaN              NaN          NaN
#
#    is_volley  is_freekick  is_deflected
# 0          0            0             0
# 1          0            0             0

# %% [markdown]
# ## Splitting game info

# %%
df[f'game_date'] = df['game'].apply(lambda x: x.split(' ', 1)[0])
df[f'game_team_h'] = df['game'].apply(lambda x: x.split(' ', 1)[1].split('-')[0])
df[f'game_team_a'] = df['game'].apply(lambda x: x.split(' ', 1)[1].split('-')[1])
df.head(2)
# Out:
#                league  season                               game minute  \
# 0  ENG-Premier League    1718  2017-08-11 Arsenal-Leicester City      2
# 1  ENG-Premier League    1718  2017-08-11 Arsenal-Leicester City      4
#
#                 player            team    xG  PSxG     outcome  distance  \
# 0  Alexandre Lacazette         Arsenal  0.06  0.37        Goal        13
# 1         Riyad Mahrez  Leicester City  0.08   NaN  Off Target        17
#
#    body_part notes    SCA_1_player  SCA_1_event     SCA_2_player  SCA_2_event  \
# 0       Head   NaN  Mohamed Elneny  Pass (Live)  Héctor Bellerín  Pass (Live)
# 1  Left Foot   NaN             NaN          NaN              NaN          NaN
#
#    is_volley  is_freekick  is_deflected   game_date game_team_h  \
# 0          0            0             0  2017-08-11     Arsenal
# 1          0            0             0  2017-08-11     Arsenal
#
#       game_team_a
# 0  Leicester City
# 1  Leicester City

# %% [markdown]
# ## Save

# %%
path_output
# Out:
# '/content/drive/My Drive/database/soccerdata/fbref/raw_clean/shot_events/'

# %%
df.to_csv(path_output + 'database.csv', index=False)
